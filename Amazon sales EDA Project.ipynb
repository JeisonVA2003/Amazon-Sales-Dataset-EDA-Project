# %% [markdown]
#  # Amazon Sales Dataset EDA

# %% [markdown]
# ## Author

# %% [markdown]
# ###  Jeison Vasquez Arcia

# %% [markdown]
# #### Contact Info
# ##### Email: jeisonvas.14@gmail.com
# [Linkedln](www.linkedin.com/in/jeison-vásquez-arcia-0723a9220)

# %% [markdown]
# ## Libraries

# %%
pip install pandas numpy matplotlib seaborn scipy
# Out:
# ...
#                                               0.0/11.3 MB ? eta -:--:--
#      -                                        0.6/11.3 MB 17.5 MB/s eta 0:00:01
#      -----                                    1.6/11.3 MB 20.6 MB/s eta 0:00:01
#      ---------                                2.6/11.3 MB 21.1 MB/s eta 0:00:01
#      --------------                           4.2/11.3 MB 24.3 MB/s eta 0:00:01
#      --------------------                     5.7/11.3 MB 26.0 MB/s eta 0:00:01
#      -------------------------                7.3/11.3 MB 29.2 MB/s eta 0:00:01
#      -------------------------------          8.9/11.3 MB 30.0 MB/s eta 0:00:01
#      --------------------------------------  11.1/11.3 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------  11.3/11.3 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------- 11.3/11.3 MB 29.8 MB/s eta 0:00:00
# ...
#                                               0.0/13.1 MB ? eta -:--:--
# ...

# %% [markdown]
# ## About Data

# %% [markdown]
# #### Title: Amazon Sales Dataset
# ##### Dataset: [link](https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset)
#
# ##### Dataset Columns Names
#
# This dataset is having the data of 1K+ Amazon Product's Ratings and Reviews as per their details listed on the official website of Amazon¶

# %% [markdown]
# ### Process
#
# Exploring the Amazon Sales Dataset follows a structured process. We begin by cleaning and preparing the data to ensure accuracy and consistency. Then, we apply descriptive statistics—such as averages and ranges—to summarize the information. After that, we use visualizations like charts and graphs to identify patterns and relationships within the dataset. We also check for outliers, which represent unusual data points, and validate our assumptions about the data. To gain deeper insights, we segment the dataset into meaningful groups. Finally, we summarize the key findings from the analysis.

# %% [markdown]
# ### Objectives
#
# The main goal of analyzing the Amazon Sales Dataset is to explore product categories, pricing, ratings, and sales patterns in order to uncover the factors that influence consumer purchasing decisions. Specifically, the analysis aims to:
#
# - Identify product characteristics that resonate with consumers and drive sales.
# - Translate insights into actionable recommendations to optimize product development, refine marketing strategies, and strengthen competitive advantage.
# - Provide businesses with knowledge to design products that align with evolving consumer needs and preferences.
# - Develop communication strategies tailored to specific demographics to maximize engagement.
# - Support the creation of a marketplace where products connect meaningfully with consumers.

# %% [markdown]
# ### Import Libraries
#
#
# We will use the following libraries
#
# **1.** Pandas: Data manipulation and analysis
#
# **2.** Numpy: Numerical operations and calculations
#
# **3.** Matplotlib: Data visualization and plotting
#
# **4.** Seaborn: Enhanced data visualization and statistical graphics
#
# **5.** Scipy: Scientific computing and advanced mathematical operations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
# this is for jupyter notebook to show the plot in the notebook itself instead of opening a new window
# %matplotlib inline

# %% [markdown]
# Data Loading and Exploration | Cleaning
#
# **Load a CSV file then creating a dataframe**

# %%
df = pd.read_csv("amazon.csv")

# %% [markdown]
# ## Sneak Peak of data

# %% [markdown]
# Quick overview of the data and identify any potential problems or areas of interest.

# %%
pd.set_option('display.max_columns', None) 
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %% [markdown]
# Column names, shape and info of the Dataset

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
print(f"The Number of Rows are {df.shape[0]}, and columns are {df.shape[1]}.")
# Out:
# The Number of Rows are 1465, and columns are 16.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# The dataset contains 1465 rows and 16 columns. The data type for all columns is object. There are a few missing values that will be handled later.
#
# ### Dataset Columns
#
# - `product_id`
# - `product_name`
# - `category`
# - `discounted_price`
# - `actual_price`
# - `discount_percentage`
# - `rating`
# - `rating_count`
# - `about_product`
# - `user_id`
# - `user_name`
# - `review_id`
# - `review_title`
# - `review_content`
# - `img_link`
# - `product_link`

# %% [markdown]
# Changing Data Types of Columns `discounted_price` , `actual_price` , `discount_percentage` , `rating` ,  `rating_count`    from object to float

# %%
df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
df['discounted_price'] = df['discounted_price'].str.replace(",",'')
df['discounted_price'] = df['discounted_price'].astype('float64')

df['actual_price'] = df['actual_price'].str.replace("₹",'')
df['actual_price'] = df['actual_price'].str.replace(",",'')
df['actual_price'] = df['actual_price'].astype('float64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
#       2 df['discounted_price'] = df['discounted_price'].str.replace(",",'')
#       3 df['discounted_price'] = df['discounted_price'].astype('float64')
#
# File c:\Users\jeiso\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# ...

# %%
df['discount_percentage'] = df['discount_percentage'].str.replace('%','').astype('float64')

df['discount_percentage'] = df['discount_percentage'] / 100

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 3.0      3
# 4.8      3
# 5.0      3
# 2.8      2
# 3.2      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %% [markdown]
# We found an unusual string in rating column `|`

# %% [markdown]
# So we are going to check the strange row

# %%
df.query('rating == "|"')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        2499.0                 0.16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %% [markdown]
# We identify that this strange string is like a missing value and we have to search the product info in Amazon
#
# I got this product rating on Amazon by searching the provided product_id on their official website (amazon.in)
# The rating is 3.9. So, I am going to give the item rating a 3.9 as well.

# %%
df['rating'] = df['rating'].str.replace('|', '3.9').astype('float64')

# %%
df['rating_count'] = df['rating_count'].str.replace(',', '').astype('float64')

# %% [markdown]
# Now we check the info of the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# Now we are going to show a collection of quantitative measures that summarize and describe the main characteristics of a dataset.
#
#
# **Descriptive Statistics**

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635             0.476915     4.096451
# std         6944.304394   10874.826864             0.216359     0.291620
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000             0.320000     4.000000
# 50%          799.000000    1650.000000             0.500000     4.100000
# 75%         1999.000000    4295.000000             0.630000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %% [markdown]
# Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# rating_count           2
# product_id             0
# category               0
# product_name           0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# We found missing values percentage in the data

# %%
round(df.isnull().sum() / len(df) * 100, 2).sort_values(ascending=False)
# Out:
# rating_count           0.14
# product_id             0.00
# category               0.00
# product_name           0.00
# discounted_price       0.00
# actual_price           0.00
# discount_percentage    0.00
# rating                 0.00
# about_product          0.00
# user_id                0.00
# user_name              0.00
# review_id              0.00
# review_title           0.00
# review_content         0.00
# img_link               0.00
# product_link           0.00
# dtype: float64

# %% [markdown]
# We are only viewing the rows where there are null values in the column.

# %%
df[df['rating_count'].isnull()].head(5)
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 282         999.0                 0.80     3.0           NaN
# 324         999.0                 0.75     5.0           NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# ...

# %% [markdown]
# Impute missing values

# %%
df['rating_count'] = df.rating_count.fillna(value=df['rating_count'].mean())

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# We have cleaned the dataset from null values

# %% [markdown]
# **Now we have to find duplications and analyse them**

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
any_duplicates = df.duplicated(subset=['product_id', 'product_name', 'category', 'discounted_price',
       'actual_price', 'discount_percentage', 'rating', 'rating_count',
       'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
       'review_content', 'img_link', 'product_link']).any()

any_duplicates
# Out:
# np.False_

# %% [markdown]
# No duplications found

# %% [markdown]
# ## Data Visualization

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 0.64     4.2       24269.0
# ...

# %% [markdown]
# We will use histograms and box plots to understand the distribution, central tendency, and spread of the numerical data

# %% [markdown]
# #### 1. Distribution of Prices (actual_price)

# %%
# Set the visual style for the plots
# sns.set_style("whitegrid")

# # Histogram for the actual price
plt.figure(figsize=(10, 6))
sns.histplot(df['actual_price'], kde=True, bins=30, color='skyblue')
plt.title('Distribution of Actual Prices', fontsize=16, weight='bold')
plt.xlabel('Actual Price ($)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# #### 2. Distribution of Ratings (rating)
# This will show us whether customers tend to leave high or low ratings.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['rating'], kde=True, bins=20, color='coral')
plt.title('Distribution of Product Ratings', fontsize=16, weight='bold')
plt.xlabel('Rating (1.0 to 5.0)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# #### 3. Distribution of Rating Counts (rating_count)
# This plot is crucial for understanding popularity. Do a few products have many reviews, or is it evenly distributed?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['rating_count'], kde=True, bins=30, color='lightgreen')
plt.title('Distribution of Rating Counts per Product', fontsize=16, weight='bold')
plt.xlabel('Number of Ratings', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# #### 4. Distribution of Product Categories (category)
# This will allow us to identify which categories have the most products in the dataset.

# %%
top_categories = df['category'].value_counts().head(15)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_categories.values, y=top_categories.index, palette='viridis', orient='h')
plt.title('Top 15 Categories by Product Count', fontsize=16, weight='bold')
plt.xlabel('Number of Products', fontsize=12)
plt.ylabel('Category', fontsize=12)
plt.show()
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_7848\4192591580.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_categories.values, y=top_categories.index, palette='viridis', orient='h')

# %% [markdown]
# ## Correlation Analysis

# %%
df_1 = df.select_dtypes(include=['float64', 'int64'])

correlation_matrix = df_1.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix, 
    annot=True,          
    cmap='coolwarm',     
    fmt='.2f',          
    linewidths=.5       
)

plt.title('Correlation Matrix of Variables (Pearson)', fontsize=16, weight='bold')
plt.show()

# %%
spearman_correlation_matrix = df_1.corr(method="spearman")
sns.heatmap(spearman_correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix (Spearman)")
plt.show()

# %%
# Calculate correlation coefficient between product price and sales
correlation_coefficient = np.corrcoef(df['actual_price'], df['rating'])[0, 1]

# Print correlation coefficient
print(correlation_coefficient)
# Out:
# 0.12174449609998352

# %% [markdown]
# ## Grouping and Aggregation

# %%
mean_ratings = df.groupby('category')['rating'].mean()

# Sort in descending order and convert to a DataFrame for better printing
sorted_ratings_df = mean_ratings.sort_values(ascending=False).reset_index()
sorted_ratings_df.rename(columns={'rating': 'average_rating'}, inplace=True)

# Print the top 10 highest-rated categories
print("--- Top 10 Highest-Rated Categories ---")
print(sorted_ratings_df.head(10))
# Out:
# --- Top 10 Highest-Rated Categories ---
#                                             category  average_rating
# 0                      Computers&Accessories|Tablets             4.6
# 1  Computers&Accessories|NetworkingDevices|Networ...             4.5
# 2   Electronics|Cameras&Photography|Accessories|Film             4.5
# 3            Computers&Accessories|Components|Memory             4.5
# 4  Electronics|HomeAudio|MediaStreamingDevices|St...             4.5
# 5  OfficeProducts|OfficeElectronics|Calculators|B...             4.5
# 6          HomeImprovement|Electrical|CordManagement             4.5
# 7  Home&Kitchen|Kitchen&HomeAppliances|Coffee,Tea...             4.5
# 8  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             4.5
# 9       Electronics|PowerAccessories|SurgeProtectors             4.5

# %%
top_15_categories = sorted_ratings_df.head(15)

plt.figure(figsize=(12, 8))
sns.barplot(
    x='average_rating', 
    y='category', 
    data=top_15_categories, 
    palette='viridis',
    orient='h'
)

# Add titles and labels for clarity
plt.title('Average Rating by Product Category (Top 15)', fontsize=16, weight='bold')
plt.xlabel('Average Rating (out of 5)', fontsize=12)
plt.ylabel('Category', fontsize=12)
plt.xlim(4, 5) # Optional: Zoom in on the high ratings if they are all close

plt.show()
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_7848\2284009223.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
top_10 = sorted_ratings_df.head(10)
bottom_10 = sorted_ratings_df.tail(10).sort_values('average_rating', ascending=True)

# Create two subplots side-by-side
fig, axes = plt.subplots(1, 2, figsize=(18, 8))
fig.suptitle('Highest and Lowest Rated Product Categories', fontsize=20, weight='bold')

# --- Plot for Top 10 ---
sns.barplot(ax=axes[0], x='average_rating', y='category', data=top_10, palette='Greens_r')
axes[0].set_title('Top 10 Highest-Rated', fontsize=16)
axes[0].set_xlabel('Average Rating')
axes[0].set_ylabel('Category')

# --- Plot for Bottom 10 ---
sns.barplot(ax=axes[1], x='average_rating', y='category', data=bottom_10, palette='Reds_r')
axes[1].set_title('Top 10 Lowest-Rated', fontsize=16)
axes[1].set_xlabel('Average Rating')
axes[1].set_ylabel('') # Hide y-label for cleaner look

plt.tight_layout(rect=[0, 0, 1, 0.96]) # Adjust layout to make space for suptitle
plt.show()
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_7848\2343486736.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[0], x='average_rating', y='category', data=top_10, palette='Greens_r')
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_7848\2343486736.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(ax=axes[1], x='average_rating', y='category', data=bottom_10, palette='Reds_r')

# %%
# 1. Group by CATEGORY and calculate the standard deviation of price
price_std_by_category = df.groupby('category')['actual_price'].std().sort_values(ascending=False)

# 2. Visualize the top 15 categories with the highest price variation
plt.figure(figsize=(12, 8))
sns.barplot(
    x=price_std_by_category.head(15).values,
    y=price_std_by_category.head(15).index,
    palette='plasma',
    orient='h'
)
plt.title('Top 15 Categories by Price Variation (Std. Deviation)', fontsize=16, weight='bold')
plt.xlabel('Standard Deviation of Price ($)')
plt.ylabel('Category')
plt.show()
# Out:
# C:\Users\jeiso\AppData\Local\Temp\ipykernel_7848\468188539.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Questions and Answers

# %% [markdown]
# #### What is the average rating for each product category?

# %%
if df["rating"].dtype == "object":
    df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# Calculate the average ratings and sort the results
average_ratings = df.groupby("category")["rating"].mean().reset_index()
average_ratings = average_ratings.sort_values(by="rating", ascending=False)

# Rename the column for clarity
average_ratings.rename(columns={'rating': 'Average Rating'}, inplace=True)

styled_table = average_ratings.head(15).style \
    .background_gradient(cmap='viridis', subset=['Average Rating']) \
    .format({'Average Rating': '{:.2f}'}) \
    .set_caption("Average Product Rating by Category") \
    .set_properties(**{'text-align': 'left'})

styled_table
# Out:
# <style type="text/css">
# #T_bae63_row0_col0, #T_bae63_row1_col0, #T_bae63_row2_col0, #T_bae63_row3_col0, #T_bae63_row4_col0, #T_bae63_row5_col0, #T_bae63_row6_col0, #T_bae63_row7_col0, #T_bae63_row8_col0, #T_bae63_row9_col0, #T_bae63_row10_col0, #T_bae63_row11_col0, #T_bae63_row12_col0, #T_bae63_row13_col0, #T_bae63_row14_col0 {
#   text-align: left;
# }
# #T_bae63_row0_col1 {
#   background-color: #fde725;
#   color: #000000;
#   text-align: left;
# }
# #T_bae63_row1_col1, #T_bae63_row2_col1, #T_bae63_row3_col1, #T_bae63_row4_col1, #T_bae63_row5_col1, #T_bae63_row6_col1, #T_bae63_row7_col1, #T_bae63_row8_col1, #T_bae63_row9_col1, #T_bae63_row10_col1 {
#   background-color: #2a788e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_bae63_row11_col1 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_bae63_row12_col1 {
#   background-color: #453781;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_bae63_row13_col1 {
#   background-color: #482475;
# ...

# %% [markdown]
# The output shows that most product categories have generally positive customer feedback, with average ratings above 3.50.

# %% [markdown]
# ### What are the top rating_count products by category?

# %%
top_reviewed_per_category = (
    df.groupby("category")
    .apply(lambda x: x.nlargest(10, "rating_count"))
    .reset_index(drop=True)
)

print(top_reviewed_per_category)
# Out:
#      product_id  \
# 0    B0912WJ87V
# 1    B097C564GC
# 2    B094DQWV9B
# 3    B009LJ2BXA
# 4    B08SCCG9D4
# ..          ...
# 815  B00LOD70SC
# 816  B07SBGFDX9
# 817  B00LZPQVMK
# 818  B0746N6WML
# 819  B00DJ5N9VK
#
#                                                                                                                                                                                                     product_name  \
# 0                              Reffair AX30 [MAX] Portable Air Purifier for Car, Home & Office | Smart Ionizer Function | H13 Grade True HEPA Filter [Internationally Tested] Aromabuds Fragrance Option - Black
# 1               rts [2 Pack] Mini USB C Type C Adapter Plug, Type C Female to USB A Male Charger Charging Cable Adapter Converter compatible for iPhone, Samsung S20 ultra/S21/S10/S8/S9/MacBook Pro iPad Silver
# ...

# %% [markdown]
# - The output highlights products likely to be popular within their categories based on high review counts, suggesting customer interest and engagement.
# - Review counts range from 9 to 15867, implying varying levels of attention and feedback across products.
# - Most listed products have ratings above 3.5, indicating a generally positive customer experience.
# - Products with the highest review counts within their categories might be considered potential top sellers, even without direct sales data.

# %% [markdown]
# ### What are the most popular product name?

# %%
pip install tabulate
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tabulate import tabulate

# Sort the DataFrame by 'rating_count' in descending order
most_popular_products = df.sort_values(by='rating_count', ascending=False)

# Select the top 10 products and the columns we want to display
top_10_table = most_popular_products[['product_name', 'rating_count', 'rating']].head(10)

# Rename columns for clarity
top_10_table.rename(columns={
    'product_name': 'Product Name',
    'rating_count': 'Number of Ratings',
    'rating': 'Avg. Rating'
}, inplace=True)

# Print the result in a clean table format
print(tabulate(top_10_table, headers='keys', tablefmt='psql', showindex=False))
# Out:
# +--------------------------------------------------------------------------------------------------------------+---------------------+---------------+
# | Product Name                                                                                                 |   Number of Ratings |   Avg. Rating |
# |--------------------------------------------------------------------------------------------------------------+---------------------+---------------|
# | Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black                                                   |              426973 |           4.4 |
# | AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot                                    |              426973 |           4.4 |
# | Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black                          |              426973 |           4.4 |
# ...

# %% [markdown]
# Based on the information in the table, the most popular product is the Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack), Black, with 426,973 ratings.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The primary goal of this project is to analyze the Amazon Sales dataset and identify insights based on the data. The Amazon Sales dataset is a valuable resource for businesses and researchers alike. It provides a wealth of information about customer behavior, product trends, and market conditions. By conducting exploratory data analysis (EDA) on this dataset, businesses can gain valuable insights that can help them make better decisions about their products, marketing, and operations.

# %% [markdown]
# ## THANKS
